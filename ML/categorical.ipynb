# %% [markdown]
# ## Импортируем нужные библиотеки

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Загружаем сырые данные о средней оценке учеников (GPA), результатах стандартизированного теста (SAT) и о посещаемости (если больше 75% занятий посещено, то - Yes)

# %%
raw_data = pd.read_csv('1.03. Dummies.csv')
raw_data
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %% [markdown]
# ### Трансформируем качественную переменную в количесвтенную,
# где Да = 1, нет = 0

# %%
 data = raw_data.copy()

# %%
data['Attendance'] = data['Attendance'].map({'Yes':1, 'No':0})

# %%
data
# Out:
#      SAT   GPA  Attendance
# 0   1714  2.40           0
# 1   1664  2.52           0
# 2   1760  2.54           0
# 3   1685  2.74           0
# 4   1693  2.83           0
# ..   ...   ...         ...
# 79  1936  3.71           1
# 80  1810  3.71           1
# 81  1987  3.73           0
# 82  1962  3.76           1
# 83  2050  3.81           1
#
# [84 rows x 3 columns]

# %%
data.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %% [markdown]
# ## Создаем регрессию

# %%
y = data['GPA']
x1 = data[['SAT','Attendance']]

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):           2.19e-15
# Time:                        14:38:46   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# ...

# %% [markdown]
# ### GPA = 0.6439 + 0.0014 * SAT + 0.2226 * Attendance,
# и если Attendance = 0, то уравнение будет GPA = 0.6439 + 0.0014 * SAT
# а для Attendance = 1: GPA = 0.8665 + 0.0014 * SAT

# %%
sns.set_style('white')
plt.figure (figsize = (8,6))
yhat_no =  0.6439 + 0.0014 * data['SAT']
yhat_yes =  0.8665 + 0.0014 * data['SAT']
plt.scatter(data['SAT'],
            y,
            c = data['Attendance'],
            cmap ='RdYlGn_r',
            s = 80,
            alpha = 0.8)
fig = plt.plot (data['SAT'],
                yhat_no,
                lw=2,
                c = 'green')
fig = plt.plot (data['SAT'],
                yhat_yes,
                lw=3,
                c = 'red')
plt.xlabel ('SAT',
            fontsize = 15,
            fontweight = 'bold')
plt.ylabel ('GPA',
            fontsize = 15,
            fontweight = 'bold')

sns.despine()
plt.show()

# %% [markdown]
# Таким образом, мы видим прямую зависимость результат SAT и средней оценки, а также, что ученики посетившиие большинство занятий (красные точки и красная линия регрессии) имеют более высокие оценки.
