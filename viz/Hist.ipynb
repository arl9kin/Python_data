# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv('C:/study/data/365data/tasks/viz/histogram_data.csv')
df
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
sns.set_style ('white')
plt.figure (figsize = (8,6))
plt.hist (df['Price'], color = '#108A99', bins = 8)
plt.title ('Distribution of Real Estate prices', fontsize = 15, fontweight = 'bold', color = 'black', loc = 'left')
plt.ylabel ('Number of Properties', fontsize = 13, fontweight = 'bold', color = 'black')
plt.xlabel ('Price in (000\' $)', fontsize = 13, fontweight = 'bold', color = 'black')
sns.despine()
plt.show()
