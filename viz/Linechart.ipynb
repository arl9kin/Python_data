# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('C:/study/data/365data/tasks/viz/line_chart_data.csv')

# %%
df.head()
# Out:
#        Date   GSPC500   FTSE100   New date
# 0  1/3/2000  0.003264  0.000000 2000-01-03
# 1  1/4/2000 -0.009549  0.000000 2000-01-04
# 2  1/5/2000 -0.038345 -0.038137 2000-01-05
# 3  1/6/2000  0.001922 -0.019502 2000-01-06
# 4  1/7/2000  0.000956 -0.013571 2000-01-07

# %%
df['New_date'] = pd.to_datetime(df['Date'])
df
# Out:
#             Date   GSPC500   FTSE100   New date   New_date
# 0       1/3/2000  0.003264  0.000000 2000-01-03 2000-01-03
# 1       1/4/2000 -0.009549  0.000000 2000-01-04 2000-01-04
# 2       1/5/2000 -0.038345 -0.038137 2000-01-05 2000-01-05
# 3       1/6/2000  0.001922 -0.019502 2000-01-06 2000-01-06
# 4       1/7/2000  0.000956 -0.013571 2000-01-07 2000-01-07
# ...          ...       ...       ...        ...        ...
# 2865  12/27/2010 -0.002282  0.002135 2010-12-27 2010-12-27
# 2866  12/28/2010  0.003539  0.000000 2010-12-28 2010-12-28
# 2867  12/29/2010 -0.000254  0.000000 2010-12-29 2010-12-29
# 2868  12/30/2010  0.000524 -0.002080 2010-12-30 2010-12-30
# 2869  12/31/2010 -0.002128 -0.004236 2010-12-31 2010-12-31
#
# [2870 rows x 5 columns]

# %%
sns.set_style('dark')
lebels = ['S&P500','FTSE100']
plt.figure (figsize = (20,8))
plt.plot(df['New_date'],df['GSPC500'])
plt.plot(df['New_date'], df['FTSE100'])
plt.title('Kek', fontsize = 20, fontweight = 'bold')
plt.ylabel ('returns', fontsize = 15)
plt.xlabel ('Date')
plt.legend (lebels, loc = 'upper left', fontsize = 'large')
plt.show()

# %%
df_H2_2008 = df[(df.New_date >= '2008-07-01') & (df.New_date <= '2008-12-31')]
df_H2_2008.tail()
# Out:
#             Date   GSPC500   FTSE100   New date   New_date
# 2343  12/25/2008  0.000000  0.000000 2008-12-25 2008-12-25
# 2344  12/26/2008  0.006529  0.000000 2008-12-26 2008-12-26
# 2345  12/29/2008  0.003289  0.000000 2008-12-29 2008-12-29
# 2346  12/30/2008 -0.002052  0.024380 2008-12-30 2008-12-30
# 2347  12/31/2008  0.022985  0.026578 2008-12-31 2008-12-31

# %%
sns.set_style('dark')
lebels = ['S&P500','FTSE100']
plt.figure (figsize = (20,8))
plt.plot(df_H2_2008['New_date'],df_H2_2008['GSPC500'], color = 'midnightblue')
plt.plot(df_H2_2008['New_date'], df_H2_2008['FTSE100'], color = 'crimson')
plt.title('Kek 2H 2008', fontsize = 20, fontweight = 'bold')
plt.ylabel ('returns', fontsize = 15)
plt.xlabel ('Date')
plt.legend (lebels, loc = 'upper left', fontsize = 'large')
plt.show()
