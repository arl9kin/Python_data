# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set()

# %%
df = pd.read_csv('C:/study/data/365data/tasks/viz/scatter_plot_ii.csv')
df
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
sns.set_style ('white')
plt.figure (figsize =(9,5))

sns.regplot(x = 'Budget',
            y = 'Sales',
            data = df,
            color = 'midnightblue',
            line_kws = {'color':'red'})
plt.xlabel("Ad exp", fontsize = 13, fontweight = 'bold')
plt.ylabel("Sales", fontsize = 13, fontweight = 'bold')
plt.title ("Effect of Ad on Sales", fontsize = 17, fontweight = 'bold', loc = 'left')
sns.despine()
plt.show()

# %%
sns.set_style ('white')

sns.lmplot(x = 'Budget',
           y = 'Sales',
           data = df,
           scatter_kws = {'color':'midnightblue'},
           line_kws = {'color':'red'},
           height = 5,
           aspect = 2)
plt.xlabel("Ad exp", fontsize = 15, fontweight = 'bold')
plt.ylabel("Sales", fontsize = 15, fontweight = 'bold')
plt.title ("Effect of Ad on Sales", fontsize = 20, fontweight = 'bold', loc = 'left')
sns.despine()
plt.show()
