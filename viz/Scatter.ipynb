# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set()

# %%
df = pd.read_csv('C:/study/data/365data/tasks/viz/scatter_data.csv')
df
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
sns.set_style ('white')
plt.figure(figsize = (12,8))
scatter = plt.scatter(df['Area (ft.)'],
            df['Price'],
            c = df['Building Type'],
            alpha = 0.7,
            cmap = 'viridis')
plt.title ('Relationship between Area and Price of California Real Esatate',
           fontsize = 17,
           fontweight = 'bold',
           loc = 'left',
           color = 'midnightblue')
plt.ylabel('Price in (000\'s $)', fontsize = 15, fontweight = 'bold')
plt.xlabel('Area (sq. ft)', fontsize = 15, fontweight = 'bold')
plt.legend(*scatter.legend_elements(),
          loc = 'upper left',
          title = 'Building Type')
plt.show()

# %%
sns.set_style ('darkgrid')
plt.figure(figsize = (12,8))
sns.scatterplot(df['Area (ft.)'],
            df['Price'],
            hue = df['Building Type'],
            alpha = 0.5,
            palette = ['black', 'darkblue', 'purple', 'pink', 'orange'],
            s = 100)

plt.title ('Relationship between Area and Price of California Real Esatate',
           fontsize = 17,
           fontweight = 'bold',
           loc = 'left',
           color = 'midnightblue')
plt.ylabel('Price in (000\'s $)', fontsize = 15, fontweight = 'bold')
plt.xlabel('Area (sq. ft)', fontsize = 15, fontweight = 'bold')
plt.legend(*scatter.legend_elements(),
          loc = 'upper left',
          title = 'Building Type')
plt.show()
